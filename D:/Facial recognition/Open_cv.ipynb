# %%
from google.colab.patches import cv2_imshow
import cv2

img = cv2.imread("img7.jpg")
cv2_imshow(img)


cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7F609E26D8A0>
# -1

# %%
### rescale
def rescale(frame, scale=0.50):
    width=int(frame.shape[1]*scale)
    height=int(frame.shape[0]*scale)
    dimensions=(width, height)

    return cv.resize(frame, dimensions, interpolation=cv.INTER_AREA)

# %%
resized_img = rescale(img)
cv2_imshow(resized_img)
# Out:
# <PIL.Image.Image image mode=RGB size=960x540 at 0x7F60AE0172B0>

# %%
###importing blank image
import numpy as np
blank=np.zeros((500,500, 3), dtype='uint8')  # len, width, and 3 channel for 3 colour
#                cv2_imshow(blank)
#   then paint image as green
#              blank[200:300, 200:300]=0,0,255
#   red=0,0,255
cv2_imshow(blank)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F60EA4379A0>
# -1

# %%
cv2.rectangle(blank, (0,0), (blank.shape[1]//2, blank.shape[0 ]//2),(0,255,0), thickness=-1)
# cv2.rectangle(blank, (0,0), (250,250), (0,0,255), thickness=2)

cv2_imshow(blank)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F609E26C370>
